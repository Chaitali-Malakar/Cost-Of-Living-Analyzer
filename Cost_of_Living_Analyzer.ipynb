# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import folium  #visualizing maps
from folium import Circle
from geopy import Nominatim   #for fetching latitute & longitute

from sklearn.preprocessing import MinMaxScaler    #feature scaling
from IPython.display import display

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9671ec99-259f-46ac-8fed-c38f87f08abd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9671ec99-259f-46ac-8fed-c38f87f08abd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cost-of-living.csv to cost-of-living.csv

# %%
city = pd.read_csv('cost-of-living.csv')

# %%
city.head()
# Out:
#                                           Unnamed: 0  ...  Quito, Ecuador
# 0                       Meal, Inexpensive Restaurant  ...            3.59
# 1  Meal for 2 People, Mid-range Restaurant, Three...  ...           31.45
# 2     McMeal at McDonalds (or Equivalent Combo Meal)  ...            5.39
# 3                  Domestic Beer (0.5 liter draught)  ...            1.35
# 4                  Imported Beer (0.33 liter bottle)  ...            2.70
#
# [5 rows x 161 columns]

# %%
locator = Nominatim(user_agent="myGeocoder")
location = locator.geocode("Saint Petersburg, Russia")

# %%
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Latitude = 59.917857350000006, Longitude = 30.380619357025516

# %%
city = city.T
city.head()
# Out:
#                                                     0   ...                                                54
# Unnamed: 0                Meal, Inexpensive Restaurant  ...  International Primary School, Yearly for 1 Child
# Saint Petersburg, Russia                          7.34  ...                                           5388.86
# Istanbul, Turkey                                  4.58  ...                                           6905.43
# Izmir, Turkey                                     3.06  ...                                           4948.41
# Helsinki, Finland                                   12  ...                                              1641
#
# [5 rows x 55 columns]

# %%
city.rename(columns=city.iloc[0], inplace = True)
city.drop(city.index[0], inplace = True)
city.head()
# Out:
#                          Meal, Inexpensive Restaurant  ... International Primary School, Yearly for 1 Child
# Saint Petersburg, Russia                         7.34  ...                                          5388.86
# Istanbul, Turkey                                 4.58  ...                                          6905.43
# Izmir, Turkey                                    3.06  ...                                          4948.41
# Helsinki, Finland                                  12  ...                                             1641
# Chisinau, Moldova                                4.67  ...                                           2679.3
#
# [5 rows x 55 columns]

# %%
city = city.reset_index()

# lets rename the index column to location
city = city.rename(columns={'index': 'Location'})
city.head()
# Out:
#                    Location  ... International Primary School, Yearly for 1 Child
# 0  Saint Petersburg, Russia  ...                                          5388.86
# 1          Istanbul, Turkey  ...                                          6905.43
# 2             Izmir, Turkey  ...                                          4948.41
# 3         Helsinki, Finland  ...                                             1641
# 4         Chisinau, Moldova  ...                                           2679.3
#
# [5 rows x 56 columns]

# %%
# lets check the column names
city.columns
# Out:
# Index(['Location', 'Meal, Inexpensive Restaurant',
#        'Meal for 2 People, Mid-range Restaurant, Three-course',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (0.5 liter draught)',
#        'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
#        'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
#        'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
#        'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)',
#        'One-way Ticket (Local Transport)',
#        'Chicken Breasts (Boneless, Skinless), (1kg)',
#        'Monthly Pass (Regular Price)', 'Gasoline (1 liter)', 'Volkswagen Golf',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
#        'Apartment (3 bedrooms) in City Centre',
#        'Apartment (3 bedrooms) Outside of Centre',
#        'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment',
#        '1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)',
#        'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
#        'Fitness Club, Monthly Fee for 1 Adult',
#        'Tennis Court Rent (1 Hour on Weekend)',
#        'Cinema, International Release, 1 Seat',
#        '1 Pair of Jeans (Levis 501 Or Similar)',
#        '1 Summer Dress in a Chain Store (Zara, H&M, ...)',
#        '1 Pair of Nike Running Shoes (Mid-Range)',
#        '1 Pair of Men Leather Business Shoes',
#        'Price per Square Meter to Buy Apartment in City Centre',
#        'Price per Square Meter to Buy Apartment Outside of Centre',
#        'Average Monthly Net Salary (After Tax)',
#        'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate',
#        'Taxi Start (Normal Tariff)', 'Taxi 1km (Normal Tariff)',
#        'Taxi 1hour Waiting (Normal Tariff)', 'Apples (1kg)', 'Oranges (1kg)',
#        'Potato (1kg)', 'Lettuce (1 head)', 'Cappuccino (regular)',
#        'Rice (white), (1kg)', 'Tomato (1kg)', 'Banana (1kg)', 'Onion (1kg)',
#        'Beef Round (1kg) (or Equivalent Back Leg Red Meat)',
#        'Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)',
#        'Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child',
#        'International Primary School, Yearly for 1 Child'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')

# It can be time consuming
from geopy.extra.rate_limiter import RateLimiter

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# 2- - create location column
city['location'] = city['Location'].apply(geocode)

# 3 - create longitude, laatitude and altitude from location column (returns tuple)
city['point'] = city['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# 4 - split point column into latitude, longitude and altitude columns
city[['latitude', 'longitude', 'altitude']] = pd.DataFrame(city['point'].tolist(), index=city.index)

# lets check the head of the data set
city.head()
# Out:
#                    Location Meal, Inexpensive Restaurant  ...  longitude altitude
# 0  Saint Petersburg, Russia                         7.34  ...  30.380619      0.0
# 1          Istanbul, Turkey                         4.58  ...  28.965165      0.0
# 2             Izmir, Turkey                         3.06  ...  27.143412      0.0
# 3         Helsinki, Finland                           12  ...  24.942747      0.0
# 4         Chisinau, Moldova                         4.67  ...  28.832292      0.0
#
# [5 rows x 61 columns]

# %%
# lets remove some unnecessary columns from the data
city = city.drop(['location','point','altitude'], axis = 1)

# lets check the column names again
city.columns
# Out:
# Index(['Location', 'Meal, Inexpensive Restaurant',
#        'Meal for 2 People, Mid-range Restaurant, Three-course',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (0.5 liter draught)',
#        'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
#        'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
#        'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
#        'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)',
#        'One-way Ticket (Local Transport)',
#        'Chicken Breasts (Boneless, Skinless), (1kg)',
#        'Monthly Pass (Regular Price)', 'Gasoline (1 liter)', 'Volkswagen Golf',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
#        'Apartment (3 bedrooms) in City Centre',
#        'Apartment (3 bedrooms) Outside of Centre',
#        'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment',
#        '1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)',
#        'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
#        'Fitness Club, Monthly Fee for 1 Adult',
#        'Tennis Court Rent (1 Hour on Weekend)',
#        'Cinema, International Release, 1 Seat',
#        '1 Pair of Jeans (Levis 501 Or Similar)',
#        '1 Summer Dress in a Chain Store (Zara, H&M, ...)',
#        '1 Pair of Nike Running Shoes (Mid-Range)',
#        '1 Pair of Men Leather Business Shoes',
#        'Price per Square Meter to Buy Apartment in City Centre',
#        'Price per Square Meter to Buy Apartment Outside of Centre',
#        'Average Monthly Net Salary (After Tax)',
#        'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate',
#        'Taxi Start (Normal Tariff)', 'Taxi 1km (Normal Tariff)',
#        'Taxi 1hour Waiting (Normal Tariff)', 'Apples (1kg)', 'Oranges (1kg)',
#        'Potato (1kg)', 'Lettuce (1 head)', 'Cappuccino (regular)',
#        'Rice (white), (1kg)', 'Tomato (1kg)', 'Banana (1kg)', 'Onion (1kg)',
#        'Beef Round (1kg) (or Equivalent Back Leg Red Meat)',
#        'Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)',
#        'Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child',
#        'International Primary School, Yearly for 1 Child', 'latitude',
#        'longitude'],
#       dtype='object')

# %% [markdown]
# ## Aggregating Features

# %%
def food(city):
    return int(round((city[['Meal, Inexpensive Restaurant',
       'Domestic Beer (0.5 liter draught)',
       'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
       'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
       'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
       'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
       'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
       'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)',
       'Chicken Breasts (Boneless, Skinless), (1kg)', 'Apples (1kg)', 'Oranges (1kg)',
       'Potato (1kg)', 'Lettuce (1 head)', 'Cappuccino (regular)',
       'Rice (white), (1kg)', 'Tomato (1kg)', 'Banana (1kg)', 'Onion (1kg)',
       'Beef Round (1kg) (or Equivalent Back Leg Red Meat)',]].mean()).mean()))

def travel(city):
    return int(round((city[['One-way Ticket (Local Transport)',
                            'Monthly Pass (Regular Price)', 'Gasoline (1 liter)',
                           'Taxi Start (Normal Tariff)', 'Taxi 1km (Normal Tariff)',
                           'Taxi 1hour Waiting (Normal Tariff)',]].mean()).mean()))

def living(city):
    return int(round((city[[ 'Volkswagen Golf',
       'Apartment (1 bedroom) in City Centre',
       'Apartment (1 bedroom) Outside of Centre',
       'Apartment (3 bedrooms) in City Centre',
       'Apartment (3 bedrooms) Outside of Centre',
       'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment',
         'Price per Square Meter to Buy Apartment in City Centre',
       'Price per Square Meter to Buy Apartment Outside of Centre',
        'Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)',]].mean()).mean()))

def lifestyle(city):
    return int(round((city[['1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)',
       'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
       'Fitness Club, Monthly Fee for 1 Adult',
       'Tennis Court Rent (1 Hour on Weekend)',
       'Cinema, International Release, 1 Seat',
       '1 Pair of Jeans (Levis 501 Or Similar)',
       '1 Summer Dress in a Chain Store (Zara, H&M, ...)',
       '1 Pair of Nike Running Shoes (Mid-Range)',
       '1 Pair of Men Leather Business Shoes', 
       'Meal for 2 People, Mid-range Restaurant, Three-course',
       'McMeal at McDonalds (or Equivalent Combo Meal)',]].mean()).mean()))

def education(city):
    return int(round((city[['Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child',
       'International Primary School, Yearly for 1 Child',]].mean()).mean()))

def income(city):
    return int(round((city[['Average Monthly Net Salary (After Tax)',
       'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate',]].mean()).mean()))

# %%
city['Food'] = city.apply(food, axis = 1)
city['Travel'] = city.apply(travel, axis = 1)
city['Living'] = city.apply(living, axis = 1)
city['Lifestyle'] = city.apply(lifestyle, axis = 1)
city['Education'] = city.apply(education, axis = 1)
city['Income'] = city.apply(income, axis = 1)

# %%
# lets split the location to fetch the country names
city['Location'].str.split(', ')[0]
# Out:
# ['Saint Petersburg', 'Russia']

# %%
# lets apply the same function on whole dataset
city['country'] = city['Location'].str.split(', ')

# lets store the second one in the country column
city['Country'] = city['country'].apply(lambda x: x[1])

#lets check the values in the country column
city['Country'].value_counts()
# Out:
# India         11
# Canada         8
# Poland         6
# Australia      5
# Romania        5
#               ..
# Kazakhstan     1
# NY             1
# Armenia        1
# Norway         1
# Tunisia        1
# Name: Country, Length: 90, dtype: int64

# %%
## lets groupby the Countries with Lifestyle Factors

city[['Country','Food','Travel',
      'Living','Lifestyle','Education','Income']].groupby(['Country']).agg('mean').style.background_gradient(cmap = 'Wistia')
# Out:
# <style  type="text/css" >
# #T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row0_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row5_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row8_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row20_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row25_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row36_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row37_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row38_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row40_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row53_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row56_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row57_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row76_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row78_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row79_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row80_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row84_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row85_col0{
#             background-color:  #ffc908;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row0_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row13_col5,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row53_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row69_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row74_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row84_col5{
#             background-color:  #ffcc09;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row0_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row18_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row19_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row53_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row62_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row83_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row86_col4{
#             background-color:  #f4f242;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row0_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row8_col5,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row18_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row67_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row79_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row80_col3{
#             background-color:  #ffd20c;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row0_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row85_col2{
#             background-color:  #ffd30d;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row0_col5,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row8_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row12_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row20_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row25_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row28_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row28_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row32_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row39_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row40_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row85_col3{
#             background-color:  #ffba00;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row1_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row2_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row3_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row6_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row6_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row7_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row9_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row10_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row10_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row11_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row13_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row16_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row19_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row21_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row23_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row31_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row34_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row35_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row41_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row42_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row43_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row45_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row47_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row49_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row50_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row51_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row52_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row55_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row61_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row62_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row63_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row66_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row68_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row70_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row72_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row75_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row81_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row82_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row83_col0,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row88_col0{
#             background-color:  #f3f244;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row1_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row40_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row43_col5,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row47_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row48_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row52_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row60_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row60_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row72_col2{
#             background-color:  #f0f550;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row1_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row6_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row18_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row61_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row66_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row68_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row80_col5{
#             background-color:  #edf759;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row1_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row10_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row12_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row27_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row35_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row63_col3{
#             background-color:  #ffe619;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row1_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row7_col5,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row61_col5,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row68_col5,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row82_col5{
#             background-color:  #e9fb69;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row1_col5,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row42_col5,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row81_col4{
#             background-color:  #e7fd71;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row2_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row3_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row7_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row35_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row50_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row62_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row81_col1,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row87_col1{
#             background-color:  #eafa65;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row2_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row62_col2{
#             background-color:  #eff654;
#             color:  #000000;
#         }#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row2_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row14_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row16_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row38_col2,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row49_col3,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row65_col4,#T_74ff5a5a_2de3_11ec_8f8b_0242ac1c0002row86_col2{
#             background-color:  #fee91e;

# %%
# Let's check out the Top 5 Most Expensive Countries for Food
plt.rcParams['figure.figsize'] = (17, 7)

plt.subplot(2, 3, 1)
x = city[['Country','Food']].sort_values(by = 'Food', ascending = False).head(5)
sns.barplot(x['Country'], x['Food'], palette = 'viridis')
plt.xticks(rotation = 5)
plt.xlabel(' ')

plt.subplot(2, 3, 2)
x = city[['Country','Travel']].sort_values(by = 'Travel', ascending = False).head(5)
sns.barplot(x['Country'], x['Travel'], palette = 'viridis')
plt.xticks(rotation = 16)
plt.xlabel(' ')

plt.subplot(2, 3, 3)
x = city[['Country','Living']].sort_values(by = 'Living', ascending = False).head(6)
sns.barplot(x['Country'], x['Living'], palette = 'viridis')
plt.xticks(rotation = 15)
plt.xlabel(' ')

plt.subplot(2, 3, 4)
x = city[['Country','Lifestyle']].sort_values(by = 'Lifestyle', ascending = False).head(5)
sns.barplot(x['Country'], x['Lifestyle'], palette = 'viridis')
plt.xticks(rotation = 15)
plt.xlabel(' ')

plt.subplot(2, 3, 5)
x = city[['Country','Education']].sort_values(by = 'Education', ascending = False).head(5)
sns.barplot(x['Country'], x['Education'], palette = 'viridis')
plt.xticks(rotation = 5)
plt.xlabel(' ')

plt.subplot(2, 3, 6)
x = city[['Country','Income']].sort_values(by = 'Income', ascending = False).head(6)
sns.barplot(x['Country'], x['Income'], palette = 'viridis')
plt.xticks(rotation = 5)
plt.xlabel(' ')

plt.suptitle('Most Expensive Countries (Expenses in Euro)', fontsize = 20)
plt.show()

# %%
# Let's check out the Top 5 Least Expensive Countries
plt.rcParams['figure.figsize'] = (17, 7)

plt.subplot(2, 3, 1)
x = city[['Country','Food']].sort_values(by = 'Food', ascending = True).head(5)
sns.barplot(x['Country'], x['Food'], palette = 'Reds')
plt.xticks(rotation = 8)
plt.xlabel(' ')

plt.subplot(2, 3, 2)
x = city[['Country','Travel']].sort_values(by = 'Travel', ascending = True).head(9)
sns.barplot(x['Country'], x['Travel'], palette = 'Reds')
plt.xticks(rotation = 16)
plt.xlabel(' ')

plt.subplot(2, 3, 3)
x = city[['Country','Living']].sort_values(by = 'Living', ascending = True).head(9)
sns.barplot(x['Country'], x['Living'], palette = 'Reds')
plt.xticks(rotation = 15)
plt.xlabel(' ')

plt.subplot(2, 3, 4)
x = city[['Country','Lifestyle']].sort_values(by = 'Lifestyle', ascending = True).head(18)
sns.barplot(x['Country'], x['Lifestyle'], palette = 'Reds')
plt.xticks(rotation = 15)
plt.xlabel(' ')

plt.subplot(2, 3, 5)
x = city[['Country','Education']].sort_values(by = 'Education', ascending = True).head(9)
sns.barplot(x['Country'], x['Education'], palette = 'Reds')
plt.xticks(rotation = 10)
plt.xlabel(' ')

plt.subplot(2, 3, 6)
x = city[['Country','Income']].sort_values(by = 'Income', ascending = True).head(6)
sns.barplot(x['Country'], x['Income'], palette = 'Reds')
plt.xticks(rotation = 10)
plt.xlabel(' ')

plt.suptitle('Least Expensive Countries (Expenses in Euro)', fontsize = 20)
plt.show()

# %%
# To find some interesting columns to plot I've sorted them by range. 
# Perhaps a better way to do this in future would be by variance.
top_range = (city.describe().loc['min',:]/city.describe().loc['max',:]).sort_values().index[2:22]
list(top_range)
# Out:
# ['Education', 'Travel', 'Income', 'Food', 'Living', 'Lifestyle']

# %%
def color_producer(val):
    if val <= city[item].quantile(.25):
        return 'forestgreen'
    elif val <= city[item].quantile(.50):
        return 'goldenrod'
    elif val <= city[item].quantile(.75):
        return 'darkred'
    else:
        return 'red'

# %%
map = folium.Map(location=[city['latitude'].mean(),
                           city['longitude'].mean()],
                 tiles='Stamen Terrain',
                 zoom_start=2)

item = top_range[0]

# Add a bubble map to the base map
for i in range(0,len(city)):
    Circle(
        location=[city.iloc[i]['latitude'], city.iloc[i]['longitude']],
        radius=120000,
        color=color_producer(city.iloc[i][item])).add_to(map)

print ('Price of: ', item)
map
# Out:
# Price of:  Education
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_258d6f2a58ed483e8a6b44b7782419fa%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_258d6f2a58ed483e8a6b44b7782419fa%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_258d6f2a58ed483e8a6b44b7782419fa%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_258d6f2a58ed483e8a6b44b7782419fa%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B32.64176969875001%2C%2014.652826267506839%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%202%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_11163adce0ea47d0acfd731cf64351c9%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//stamen-tiles-%7Bs%7D.a.ssl.fastly.net/terrain/%7Bz%7D/%7Bx%7D/%7By%7D.jpg%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22% ...

# %%
map = folium.Map(location=[city['latitude'].mean(),
                           city['longitude'].mean()],
                 tiles='CartoDB dark_matter',
                 zoom_start=2)

item = top_range[1]

# Add a bubble map to the base map
for i in range(0,len(city)):
    Circle(
        location=[city.iloc[i]['latitude'], city.iloc[i]['longitude']],
        radius=120000,
        color=color_producer(city.iloc[i][item])).add_to(map)

print ('Price of: ', item)
map
# Out:
# Price of:  Travel
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_7da8fd0a9d4f4eaa840f028e71d7d348%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7da8fd0a9d4f4eaa840f028e71d7d348%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_7da8fd0a9d4f4eaa840f028e71d7d348%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_7da8fd0a9d4f4eaa840f028e71d7d348%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B32.64176969875001%2C%2014.652826267506839%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%202%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_13dda771a2c74ec0844723af101d6dbb%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/dark_all/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attri ...

# %%
map = folium.Map(location=[city['latitude'].mean(),
                           city['longitude'].mean()],
                 tiles='Stamen Toner',
                 zoom_start=2)

item = top_range[2]

# Add a bubble map to the base map
for i in range(0,len(city)):
    Circle(
        location=[city.iloc[i]['latitude'], city.iloc[i]['longitude']],
        radius=120000,
        color=color_producer(city.iloc[i][item])).add_to(map)

print ('Price of: ', item)
map
# Out:
# Price of:  Income
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_cbb1d8c6a66547138779191030f7a0a8%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cbb1d8c6a66547138779191030f7a0a8%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_cbb1d8c6a66547138779191030f7a0a8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_cbb1d8c6a66547138779191030f7a0a8%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B32.64176969875001%2C%2014.652826267506839%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%202%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_e46898662e034313a23fffbf371a223e%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//stamen-tiles-%7Bs%7D.a.ssl.fastly.net/toner/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A ...

# %%
map = folium.Map(location=[city['latitude'].mean(),
                           city['longitude'].mean()],
                 tiles='Stamen Watercolor',
                 zoom_start=2)

item = top_range[3]

# Add a bubble map to the base map
for i in range(0,len(city)):
    Circle(
        location=[city.iloc[i]['latitude'], city.iloc[i]['longitude']],
        radius=120000,
        color=color_producer(city.iloc[i][item])).add_to(map)

print ('Price of: ', item)
map
# Out:
# Price of:  Food
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_1fa49965449a47e8ae7adb8baa96fbdb%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1fa49965449a47e8ae7adb8baa96fbdb%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_1fa49965449a47e8ae7adb8baa96fbdb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_1fa49965449a47e8ae7adb8baa96fbdb%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B32.64176969875001%2C%2014.652826267506839%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%202%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_89b2a2fafd3f42c295348339e70f9917%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//stamen-tiles-%7Bs%7D.a.ssl.fastly.net/watercolor/%7Bz%7D/%7Bx%7D/%7By%7D.jpg%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution% ...

# %%
map = folium.Map(location=[city['latitude'].mean(),
                           city['longitude'].mean()],
                 tiles='Open Street Map',
                 zoom_start=2)

item = top_range[4]

# Add a bubble map to the base map
for i in range(0,len(city)):
    Circle(
        location=[city.iloc[i]['latitude'], city.iloc[i]['longitude']],
        radius=120000,
        color=color_producer(city.iloc[i][item])).add_to(map)

print ('Price of: ', item)
map
# Out:
# Price of:  Living
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_9fbf00c8485149ff809436819f10de74%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9fbf00c8485149ff809436819f10de74%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_9fbf00c8485149ff809436819f10de74%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_9fbf00c8485149ff809436819f10de74%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B32.64176969875001%2C%2014.652826267506839%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%202%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_649f0a8d43ba45b7bbef78c34cef703e%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A ...

# %%
map = folium.Map(location=[city['latitude'].mean(),
                           city['longitude'].mean()],
                 tiles='CartoDB Positron',
                 zoom_start=2)

item = top_range[5]

# Add a bubble map to the base map
for i in range(0,len(city)):
    Circle(
        location=[city.iloc[i]['latitude'], city.iloc[i]['longitude']],
        radius=120000,
        color=color_producer(city.iloc[i][item])).add_to(map)

print ('Price of: ', item)
map
# Out:
# Price of:  Lifestyle
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_7e2d0b3e83c94144a59f7f2865e40199%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7e2d0b3e83c94144a59f7f2865e40199%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_7e2d0b3e83c94144a59f7f2865e40199%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_7e2d0b3e83c94144a59f7f2865e40199%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B32.64176969875001%2C%2014.652826267506839%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%202%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_188edab58000486dbb05a72e1dbe93b1%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/light_all/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attr ...

# %%
plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('fivethirtyeight')

sns.heatmap(city[['Food','Travel','Living','Lifestyle','Education','Income']].corr(),
            cmap = 'magma', 
            annot = True, linecolor='black', linewidths = 10)
plt.title('Correlation between Major Life Style Factors', fontsize = 20)
plt.show()

# %% [markdown]
# ## Comparing Some of the Most Popular Countries in the World

# %%
city[(city['Country'] == 'United Kingdom') | (city['Country'] == 'Australia') | 
     (city['Country'] == 'Germany') | (city['Country'] == 'China') | 
    (city['Country'] == 'Russia')][['Location','Food', 
                'Travel','Living','Lifestyle','Education',
                    'Income']].set_index('Location').sort_values(by = 'Income',
                                ascending = False).style.background_gradient(cmap = 'copper')
# Out:
# <style  type="text/css" >
# #T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row0_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row0_col5,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row1_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row3_col1,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row3_col2,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row5_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row7_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row11_col4{
#             background-color:  #ffc77f;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row0_col1,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row2_col4,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row6_col1,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row7_col4{
#             background-color:  #b17047;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row0_col2{
#             background-color:  #160e09;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row0_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row2_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row8_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row9_col3{
#             background-color:  #b8744a;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row0_col4,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row9_col2{
#             background-color:  #6e462c;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row1_col1{
#             background-color:  #f19861;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row1_col2{
#             background-color:  #623e27;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row1_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row3_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row6_col3{
#             background-color:  #ffa66a;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row1_col4{
#             background-color:  #a36742;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row1_col5{
#             background-color:  #ffc67e;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row2_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row3_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row4_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row5_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row8_col0{
#             background-color:  #d28555;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row2_col1,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row7_col1{
#             background-color:  #a76943;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row2_col2{
#             background-color:  #3b2518;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row2_col5{
#             background-color:  #ffb573;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row3_col4{
#             background-color:  #ffc57d;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row3_col5{
#             background-color:  #ffb271;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row4_col1{
#             background-color:  #784c30;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row4_col2,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row13_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row14_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row15_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row15_col1,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row15_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row15_col4,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row15_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row4_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row13_col3{
#             background-color:  #342115;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row4_col4{
#             background-color:  #643f28;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row4_col5{
#             background-color:  #ffaa6c;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row5_col1{
#             background-color:  #825234;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row5_col2{
#             background-color:  #d08354;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row5_col4{
#             background-color:  #8c5838;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row5_col5{
#             background-color:  #ffa96b;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row6_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row7_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row9_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row10_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row11_col0,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row12_col0{
#             background-color:  #69422a;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row6_col2{
#             background-color:  #a96b44;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row6_col4{
#             background-color:  #9f6540;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row6_col5{
#             background-color:  #ffa86b;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row7_col2{
#             background-color:  #6b442b;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row7_col5{
#             background-color:  #fea166;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row8_col1,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row9_col1{
#             background-color:  #9e6440;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row8_col2,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row10_col3,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row14_col3{
#             background-color:  #1a100a;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row8_col4{
#             background-color:  #9a623e;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row8_col5{
#             background-color:  #fa9e64;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row9_col4{
#             background-color:  #41291a;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row9_col5{
#             background-color:  #e18e5b;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row10_col1,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row11_col1,#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row14_col1{
#             background-color:  #1b110b;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row10_col2{
#             background-color:  #915b3a;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row10_col4{
#             background-color:  #ffb070;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row10_col5{
#             background-color:  #543522;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row11_col2{
#             background-color:  #935d3b;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row11_col3{
#             background-color:  #4f3220;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row11_col5{
#             background-color:  #523421;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row12_col1{
#             background-color:  #25170f;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row12_col2{
#             background-color:  #68422a;
#             color:  #f1f1f1;
#         }#T_af434a6e_2de3_11ec_8f8b_0242ac1c0002row12_col3{
#             background-color:  #ed9660;
#             color:  #000000;
#         }#T_af434a6e_2de3_11ec

# %%
# let's plot the Indian Cities to understand them better
city['City'] = city['Location'].str.split(', ')
city['City'] = city['City'].apply(lambda x: x[0])

x = city[city['Country'] == 'India']

plt.rcParams['figure.figsize'] = (15, 15)
plt.subplot(3, 2, 1)
sns.barplot(y = x['City'], x = x['Travel'], palette = 'spring')
plt.ylabel(" ")

plt.subplot(3, 2, 2)
sns.barplot(y = x['City'], x = x['Living'], palette = 'spring')
plt.ylabel(" ")

plt.subplot(3, 2, 3)
sns.barplot(y = x['City'], x = x['Lifestyle'], palette = 'spring')
plt.ylabel(" ")

plt.subplot(3, 2, 4)
sns.barplot(y = x['City'], x = x['Education'], palette = 'spring')
plt.ylabel(" ")

plt.subplot(3, 2, 5)
sns.barplot(y = x['City'], x = x['Income'], palette = 'spring')
plt.ylabel(" ")

plt.suptitle('Comparison of Indian Cities', fontsize = 30)
plt.show()

# %%
# lets find out the List of Most Expensive Countries to Live in
x = city[['Food','Travel','Living','Lifestyle','Education','Income']]
mm = MinMaxScaler()
data = mm.fit_transform(x)
data = pd.DataFrame(data)
data.columns = x.columns
data.head()
# Out:
#        Food    Travel    Living  Lifestyle  Education    Income
# 0  0.142857  0.194444  0.139139   0.372549   0.139049  0.074890
# 1  0.142857  0.138889  0.161588   0.156863   0.177913  0.043424
# 2  0.142857  0.111111  0.155125   0.078431   0.121129  0.036816
# 3  0.428571  0.527778  0.252539   0.568627   0.032424  0.346759
# 4  0.142857  0.027778  0.082583   0.333333   0.057568  0.018250

# %%
data['Total Score'] = (data['Food'] + data['Travel'] + data['Living'] + 
                       data['Lifestyle'] + data['Education'] + data['Income'])/6

# concat city
cities = city[['City', 'Country']]
data = pd.concat([data, cities], axis = 1)
# lets sort the values
print("Most Expensive Places in the World\n")
data[['Country','City','Total Score']].sort_values(by = 'Total Score', ascending = False).head(10)
# Out:
# Most Expensive Places in the World
#             Country           City  Total Score
# 144     Switzerland         Zurich     0.790375
# 78               NY       New York     0.670422
# 100              CA  San Francisco     0.660000
# 39        Singapore      Singapore     0.576437
# 70   United Kingdom         London     0.558841
# 128         Iceland      Reykjavik     0.557198
# 102              WA        Seattle     0.539670
# 50           Norway           Oslo     0.534259
# 47               MA         Boston     0.525962
# 71               CA    Los Angeles     0.487471

# %%
# Cheapest places to live

print("Cheapest Places in the World\n")
data[['Country','City','Total Score']].sort_values(by = 'Total Score', ascending = True).head(10)
# Out:
# Cheapest Places in the World
#        Country        City  Total Score
# 123      India     Kolkata     0.042501
# 106      India   Ahmedabad     0.043629
# 112      India     Chennai     0.056045
# 63     Georgia     Tbilisi     0.057976
# 118      India   Hyderabad     0.060394
# 81       India  Chandigarh     0.063713
# 130      India        Pune     0.069141
# 82   Sri Lanka     Colombo     0.069626
# 114      India       Delhi     0.070959
# 127      India      Mumbai     0.071562

# %% [markdown]
# ### Analyzing Cost of Essential Items

# %%
city.columns
# Out:
# Index(['Location', 'Meal, Inexpensive Restaurant',
#        'Meal for 2 People, Mid-range Restaurant, Three-course',
#        'McMeal at McDonalds (or Equivalent Combo Meal)',
#        'Domestic Beer (0.5 liter draught)',
#        'Imported Beer (0.33 liter bottle)', 'Coke/Pepsi (0.33 liter bottle)',
#        'Water (0.33 liter bottle) ', 'Milk (regular), (1 liter)',
#        'Loaf of Fresh White Bread (500g)', 'Eggs (regular) (12)',
#        'Local Cheese (1kg)', 'Water (1.5 liter bottle)',
#        'Bottle of Wine (Mid-Range)', 'Domestic Beer (0.5 liter bottle)',
#        'Imported Beer (0.33 liter bottle)', 'Cigarettes 20 Pack (Marlboro)',
#        'One-way Ticket (Local Transport)',
#        'Chicken Breasts (Boneless, Skinless), (1kg)',
#        'Monthly Pass (Regular Price)', 'Gasoline (1 liter)', 'Volkswagen Golf',
#        'Apartment (1 bedroom) in City Centre',
#        'Apartment (1 bedroom) Outside of Centre',
#        'Apartment (3 bedrooms) in City Centre',
#        'Apartment (3 bedrooms) Outside of Centre',
#        'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment',
#        '1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans)',
#        'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
#        'Fitness Club, Monthly Fee for 1 Adult',
#        'Tennis Court Rent (1 Hour on Weekend)',
#        'Cinema, International Release, 1 Seat',
#        '1 Pair of Jeans (Levis 501 Or Similar)',
#        '1 Summer Dress in a Chain Store (Zara, H&M, ...)',
#        '1 Pair of Nike Running Shoes (Mid-Range)',
#        '1 Pair of Men Leather Business Shoes',
#        'Price per Square Meter to Buy Apartment in City Centre',
#        'Price per Square Meter to Buy Apartment Outside of Centre',
#        'Average Monthly Net Salary (After Tax)',
#        'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate',
#        'Taxi Start (Normal Tariff)', 'Taxi 1km (Normal Tariff)',
#        'Taxi 1hour Waiting (Normal Tariff)', 'Apples (1kg)', 'Oranges (1kg)',
#        'Potato (1kg)', 'Lettuce (1 head)', 'Cappuccino (regular)',
#        'Rice (white), (1kg)', 'Tomato (1kg)', 'Banana (1kg)', 'Onion (1kg)',
#        'Beef Round (1kg) (or Equivalent Back Leg Red Meat)',
#        'Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)',
#        'Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child',
#        'International Primary School, Yearly for 1 Child', 'latitude',
#        'longitude', 'Food', 'Travel', 'Living', 'Lifestyle', 'Education',
#        'Income', 'country', 'Country', 'City'],
#       dtype='object')

# %%
# We know that the Most common things in day to day life are
# Internet, Basic Food ItemS such as Eggs, Milk, Breads, Electricity and Water, Taxi Travel

x = city[['Country','City','Milk (regular), (1 liter)',
         'Eggs (regular) (12)', 'Loaf of Fresh White Bread (500g)',
         'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)',
         'Taxi 1km (Normal Tariff)',
         'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment',
          ]]

# lets rename these columns
x = x.rename(columns = {'Milk (regular), (1 liter)':'Milk','Eggs (regular) (12)':'Eggs', 
                       'Loaf of Fresh White Bread (500g)': 'Bread',
                       'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)': 'Internet',
                       'Taxi 1km (Normal Tariff)':'Taxi Travel',
                       'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment':'Electricity and Water'})
x.head()
# Out:
#    Country              City  Milk  ... Internet Taxi Travel Electricity and Water
# 0   Russia  Saint Petersburg  0.98  ...     6.96        0.26                102.17
# 1   Turkey          Istanbul  0.71  ...     14.2        0.47                 59.33
# 2   Turkey             Izmir  0.65  ...    12.89        0.57                 51.07
# 3  Finland          Helsinki  0.96  ...    22.31           1                 82.66
# 4  Moldova          Chisinau  0.68  ...     8.58        0.18                113.46
#
# [5 rows x 8 columns]

# %%
x.dtypes
# Out:
# Country                  object
# City                     object
# Milk                     object
# Eggs                     object
# Bread                    object
# Internet                 object
# Taxi Travel              object
# Electricity and Water    object
# dtype: object

# %%
x[['Milk','Bread','Eggs','Internet','Taxi Travel','Electricity and Water']].astype('float').describe()
# Out:
#              Milk       Bread  ...  Taxi Travel  Electricity and Water
# count  160.000000  160.000000  ...   160.000000             160.000000
# mean     0.998938    1.197875  ...     0.922250             107.106125
# std      0.391720    0.760670  ...     0.709011              51.553830
# min      0.390000    0.100000  ...     0.140000              18.560000
# 25%      0.710000    0.555000  ...     0.405000              63.860000
# 50%      0.895000    1.020000  ...     0.630000             102.465000
# 75%      1.170000    1.690000  ...     1.350000             145.707500
# max      2.640000    3.330000  ...     4.160000             265.520000
#
# [8 rows x 6 columns]

# %%
plt.rcParams['figure.figsize'] = (10, 3)
# lets check those Countries where Milk is very Expensive
print(x[x['Milk'] > 1.17][['Country','City','Milk']].sort_values(by = 'Milk',
                                    ascending = False).head(5).set_index('Country'))

print('\n')
# lets check those Countries where Bread is very Expensive
print(x[x['Bread'] > 1.69][['Country','City','Bread']].sort_values(by = 'Bread',
                                    ascending = False).head(5).set_index('Country'))

print('\n')
# lets check those Countries where Bread is very Expensive
print(x[x['Eggs'] > 2.35][['Country','City','Eggs']].sort_values(by = 'Eggs',
                                    ascending = False).head(5).set_index('Country'))

print('\n')
# lets check those Countries where Bread is very Expensive
print(x[x['Internet'] > 43.37][['Country','City','Internet']].sort_values(by = 'Internet',
                                    ascending = False).head(5).set_index('Country'))

print('\n')
# lets check those Countries where Bread is very Expensive
print(x[x['Taxi Travel'] > 1.35][['Country','City','Taxi Travel']].sort_values(by = 'Taxi Travel',
                                    ascending = False).head(5).set_index('Country'))

print('\n')
# lets check those Countries where Bread is very Expensive
print(x[x['Electricity and Water'] > 145.7][['Country','City',
                        'Electricity and Water']].sort_values(by = 'Electricity and Water',
                                    ascending = False).head(5).set_index('Country'))
# Out:
#                   City  Milk
# Country
# Taiwan          Taipei  2.64
# Hong Kong    Hong Kong  2.54
# China         Shanghai  2.39
# Singapore    Singapore  2.04
# South Korea      Seoul  1.95
#
#
#                   City Bread
# Country
# NY            New York  3.33
# CA           San Diego  3.27
# CA       San Francisco  3.12
# CA         Los Angeles  2.99
# Norway            Oslo  2.92
#
#
#                   City  Eggs
# Country
# Switzerland     Zurich  5.33
# Iceland      Reykjavik   4.8
# Norway            Oslo  3.79
# France           Paris   3.4
# Israel       Jerusalem  3.32
#
#
#                            City Internet
# Country
# United Arab Emirates  Abu Dhabi    93.29
# United Arab Emirates      Dubai    90.42
# Qatar                      Doha    78.31
# AZ                      Phoenix    67.23
# Costa Rica             San Jose     65.3
#
#
#                              City Taxi Travel
# Country
# Switzerland                Zurich        4.16
# Japan                       Tokyo        3.44
# Netherlands             Eindhoven           3
# United Kingdom             London        2.97
# Dominican Republic  Santo Domingo        2.55
#
#
#                City Electricity and Water
# Country
# Germany   Frankfurt                265.52
# Germany      Munich                242.66
# Germany     Hamburg                232.62
# Germany      Berlin                 231.8
# Slovenia  Ljubljana                199.61

# %% [markdown]
# ### Analyzing Quality of Life

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3e63fb9f-be3c-4e27-9f87-7b2ac326cd3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e63fb9f-be3c-4e27-9f87-7b2ac326cd3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movehubqualityoflife.csv to movehubqualityoflife.csv

# %%
life = pd.read_csv('movehubqualityoflife.csv')
life.head()
# Out:
#            City  Movehub Rating  ...  Quality of Life  Crime Rating
# 0       Caracas           65.18  ...             8.61         85.70
# 1  Johannesburg           84.08  ...            51.26         83.93
# 2     Fortaleza           80.17  ...            36.68         78.65
# 3   Saint Louis           85.25  ...            87.51         78.13
# 4   Mexico City           75.07  ...            27.91         77.86
#
# [5 rows x 7 columns]

# %%
# analyzing the factors describing quality of life
life.describe()
# Out:
#        Movehub Rating  Purchase Power  ...  Quality of Life  Crime Rating
# count      216.000000      216.000000  ...       216.000000    216.000000
# mean        79.676713       46.477176  ...        59.994537     41.338611
# std          6.501011       20.614519  ...        22.019376     16.416409
# min         59.880000        6.380000  ...         5.290000      9.110000
# 25%         75.070000       28.815000  ...        42.752500     29.375000
# 50%         81.060000       49.220000  ...        65.150000     41.140000
# 75%         84.020000       61.607500  ...        78.617500     51.327500
# max        100.000000       91.850000  ...        97.910000     85.700000
#
# [8 rows x 6 columns]

# %%
# lets analyze the Quality of Life

print('Cities having Best Quality of life')
display(life[['City','Quality of Life']].sort_values(by = 'Quality of Life',
                            ascending = False).head(10).set_index('City').style.background_gradient(cmap = 'Reds'))

print('Cities having Worst Quality of life')
display(life[['City','Quality of Life']].sort_values(by = 'Quality of Life',
                            ascending = True).head(10).set_index('City').style.background_gradient(cmap = 'Reds'))
# Out:
# Cities having Best Quality of life
# <style  type="text/css" >
# #T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row0_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row1_col0{
#             background-color:  #fb7353;
#             color:  #000000;
#         }#T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row2_col0{
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }#T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row3_col0{
#             background-color:  #fcb79c;
#             color:  #000000;
#         }#T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row4_col0{
#             background-color:  #fdccb8;
#             color:  #000000;
#         }#T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row5_col0{
#             background-color:  #fdd1be;
#             color:  #000000;
#         }#T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row6_col0{
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }#T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row7_col0{
#             background-color:  #fedbcc;
#             color:  #000000;
#         }#T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row8_col0{
#             background-color:  #fee7db;
#             color:  #000000;
#         }#T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row9_col0{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Quality of Life</th>    </tr>    <tr>        <th class="index_name level0" >City</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row0" class="row_heading level0 row0" >Zurich</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row0_col0" class="data row0 col0" >97.910000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row1" class="row_heading level0 row1" >Canberra</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row1_col0" class="data row1 col0" >93.050000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row2" class="row_heading level0 row2" >Adelaide</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row2_col0" class="data row2 col0" >91.540000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row3" class="row_heading level0 row3" >Berlin</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row3_col0" class="data row3 col0" >91.170000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row4" class="row_heading level0 row4" >Aachen</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row4_col0" class="data row4 col0" >90.520000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row5" class="row_heading level0 row5" >Stuttgart</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row5_col0" class="data row5 col0" >90.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row6" class="row_heading level0 row6" >Dresden</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row6_col0" class="data row6 col0" >90.210000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row7" class="row_heading level0 row7" >Munich</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row7_col0" class="data row7 col0" >90.080000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row8" class="row_heading level0 row8" >Edmonton</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row8_col0" class="data row8 col0" >89.580000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002level0_row9" class="row_heading level0 row9" >Portland</th>
#                         <td id="T_1c330d30_2de4_11ec_8f8b_0242ac1c0002row9_col0" class="data row9 col0" >88.760000</td>
#             </tr>
#     </tbody></table>
# Cities having Worst Quality of life
# <style  type="text/css" >
# #T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row0_col0{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row1_col0{
#             background-color:  #fcbba1;
#             color:  #000000;
#         }#T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row2_col0{
#             background-color:  #f24633;
#             color:  #000000;
#         }#T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row3_col0{
#             background-color:  #f03d2d;
#             color:  #f1f1f1;
#         }#T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row4_col0,#T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row5_col0{
#             background-color:  #dd2a25;
#             color:  #f1f1f1;
#         }#T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row6_col0{
#             background-color:  #c1161b;
#             color:  #f1f1f1;
#         }#T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row7_col0{
#             background-color:  #980c13;
#             color:  #f1f1f1;
#         }#T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row8_col0{
#             background-color:  #960b13;
#             color:  #f1f1f1;
#         }#T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row9_col0{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Quality of Life</th>    </tr>    <tr>        <th class="index_name level0" >City</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row0" class="row_heading level0 row0" >Hanoi</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row0_col0" class="data row0 col0" >5.290000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row1" class="row_heading level0 row1" >Caracas</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row1_col0" class="data row1 col0" >8.610000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row2" class="row_heading level0 row2" >Manila</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row2_col0" class="data row2 col0" >13.140000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row3" class="row_heading level0 row3" >Dhaka</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row3_col0" class="data row3 col0" >13.480000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row4" class="row_heading level0 row4" >Tehran</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row4_col0" class="data row4 col0" >14.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row5" class="row_heading level0 row5" >Nairobi</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row5_col0" class="data row5 col0" >14.360000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row6" class="row_heading level0 row6" >Jakarta</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row6_col0" class="data row6 col0" >15.660000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row7" class="row_heading level0 row7" >Baku</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row7_col0" class="data row7 col0" >17.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row8" class="row_heading level0 row8" >Cairo</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row8_col0" class="data row8 col0" >17.250000</td>
#             </tr>
#             <tr>
#                         <th id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002level0_row9" class="row_heading level0 row9" >Karachi</th>
#                         <td id="T_1c354d02_2de4_11ec_8f8b_0242ac1c0002row9_col0" class="data row9 col0" >18.500000</td>
#             </tr>
#     </tbody></table>

# %%
# lets analyze the heath care of cities

print('Cities having Best Health care Facility')
display(life[['City','Health Care']].sort_values(by = 'Health Care',
                            ascending = False).head(10).set_index('City').style.background_gradient(cmap = 'Greens'))

print('Cities having Worst Health care Facility')
display(life[['City', 'Health Care']].sort_values(by = 'Health Care',
                            ascending = True).head(10).set_index('City').style.background_gradient(cmap = 'Greens'))
# Out:
# Cities having Best Health care Facility
# <style  type="text/css" >
# #T_208bd074_2de4_11ec_8f8b_0242ac1c0002row0_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_208bd074_2de4_11ec_8f8b_0242ac1c0002row1_col0{
#             background-color:  #7cc87c;
#             color:  #000000;
#         }#T_208bd074_2de4_11ec_8f8b_0242ac1c0002row2_col0{
#             background-color:  #91d28e;
#             color:  #000000;
#         }#T_208bd074_2de4_11ec_8f8b_0242ac1c0002row3_col0{
#             background-color:  #b7e2b1;
#             color:  #000000;
#         }#T_208bd074_2de4_11ec_8f8b_0242ac1c0002row4_col0,#T_208bd074_2de4_11ec_8f8b_0242ac1c0002row5_col0,#T_208bd074_2de4_11ec_8f8b_0242ac1c0002row6_col0{
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }#T_208bd074_2de4_11ec_8f8b_0242ac1c0002row7_col0{
#             background-color:  #eff9eb;
#             color:  #000000;
#         }#T_208bd074_2de4_11ec_8f8b_0242ac1c0002row8_col0{
#             background-color:  #f3faf0;
#             color:  #000000;
#         }#T_208bd074_2de4_11ec_8f8b_0242ac1c0002row9_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Health Care</th>    </tr>    <tr>        <th class="index_name level0" >City</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row0" class="row_heading level0 row0" >Bangkok</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row0_col0" class="data row0 col0" >95.960000</td>
#             </tr>
#             <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row1" class="row_heading level0 row1" >Canberra</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row1_col0" class="data row1 col0" >91.900000</td>
#             </tr>
#             <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row2" class="row_heading level0 row2" >Pattaya</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row2_col0" class="data row2 col0" >91.460000</td>
#             </tr>
#             <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row3" class="row_heading level0 row3" >Glasgow</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row3_col0" class="data row3 col0" >90.550000</td>
#             </tr>
#             <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row4" class="row_heading level0 row4" >Taipei</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row4_col0" class="data row4 col0" >88.890000</td>
#             </tr>
#             <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row5" class="row_heading level0 row5" >Brisbane</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row5_col0" class="data row5 col0" >88.890000</td>
#             </tr>
#             <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row6" class="row_heading level0 row6" >Bristol</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row6_col0" class="data row6 col0" >88.890000</td>
#             </tr>
#             <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row7" class="row_heading level0 row7" >Lyon</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row7_col0" class="data row7 col0" >88.650000</td>
#             </tr>
#             <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row8" class="row_heading level0 row8" >Munich</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row8_col0" class="data row8 col0" >88.430000</td>
#             </tr>
#             <tr>
#                         <th id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002level0_row9" class="row_heading level0 row9" >Oslo</th>
#                         <td id="T_208bd074_2de4_11ec_8f8b_0242ac1c0002row9_col0" class="data row9 col0" >88.190000</td>
#             </tr>
#     </tbody></table>
# Cities having Worst Health care Facility
# <style  type="text/css" >
# #T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row0_col0,#T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row1_col0{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row2_col0{
#             background-color:  #88ce87;
#             color:  #000000;
#         }#T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row3_col0{
#             background-color:  #73c476;
#             color:  #000000;
#         }#T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row4_col0,#T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row5_col0{
#             background-color:  #369f54;
#             color:  #000000;
#         }#T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row6_col0{
#             background-color:  #258d47;
#             color:  #000000;
#         }#T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row7_col0{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row8_col0{
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }#T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row9_col0{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Health Care</th>    </tr>    <tr>        <th class="index_name level0" >City</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row0" class="row_heading level0 row0" >Dhaka</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row0_col0" class="data row0 col0" >20.830000</td>
#             </tr>
#             <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row1" class="row_heading level0 row1" >Hanoi</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row1_col0" class="data row1 col0" >20.830000</td>
#             </tr>
#             <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row2" class="row_heading level0 row2" >Gaborone</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row2_col0" class="data row2 col0" >27.780000</td>
#             </tr>
#             <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row3" class="row_heading level0 row3" >Baku</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row3_col0" class="data row3 col0" >28.700000</td>
#             </tr>
#             <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row4" class="row_heading level0 row4" >Kolkata</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row4_col0" class="data row4 col0" >31.290000</td>
#             </tr>
#             <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row5" class="row_heading level0 row5" >Indore</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row5_col0" class="data row5 col0" >31.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row6" class="row_heading level0 row6" >Quito</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row6_col0" class="data row6 col0" >32.410000</td>
#             </tr>
#             <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row7" class="row_heading level0 row7" >Belfast</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row7_col0" class="data row7 col0" >33.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row8" class="row_heading level0 row8" >Kharkiv</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row8_col0" class="data row8 col0" >35.060000</td>
#             </tr>
#             <tr>
#                         <th id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002level0_row9" class="row_heading level0 row9" >Kiev</th>
#                         <td id="T_208f0f78_2de4_11ec_8f8b_0242ac1c0002row9_col0" class="data row9 col0" >36.480000</td>
#             </tr>
#     </tbody></table>

# %%
# lets analyze the Crime Rate

print('Cities having Highest Crime Rate')
display(life[['City','Crime Rating']].sort_values(by = 'Crime Rating',
                            ascending = False).head(10).set_index('City').style.background_gradient(cmap = 'bone'))

print('Cities having Worst Health care Facility')
display(life[['City', 'Crime Rating']].sort_values(by = 'Crime Rating',
                            ascending = True).head(10).set_index('City').style.background_gradient(cmap = 'bone'))
# Out:
# Cities having Highest Crime Rate
# <style  type="text/css" >
# #T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row0_col0{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row1_col0{
#             background-color:  #cadddd;
#             color:  #000000;
#         }#T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row2_col0{
#             background-color:  #565776;
#             color:  #f1f1f1;
#         }#T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row3_col0{
#             background-color:  #4b4b69;
#             color:  #f1f1f1;
#         }#T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row4_col0{
#             background-color:  #464661;
#             color:  #f1f1f1;
#         }#T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row5_col0{
#             background-color:  #2f2f42;
#             color:  #f1f1f1;
#         }#T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row6_col0{
#             background-color:  #2b2b3c;
#             color:  #f1f1f1;
#         }#T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row7_col0{
#             background-color:  #0e0e13;
#             color:  #f1f1f1;
#         }#T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row8_col0{
#             background-color:  #020202;
#             color:  #f1f1f1;
#         }#T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row9_col0{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Crime Rating</th>    </tr>    <tr>        <th class="index_name level0" >City</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row0" class="row_heading level0 row0" >Caracas</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row0_col0" class="data row0 col0" >85.700000</td>
#             </tr>
#             <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row1" class="row_heading level0 row1" >Johannesburg</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row1_col0" class="data row1 col0" >83.930000</td>
#             </tr>
#             <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row2" class="row_heading level0 row2" >Fortaleza</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row2_col0" class="data row2 col0" >78.650000</td>
#             </tr>
#             <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row3" class="row_heading level0 row3" >Saint Louis</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row3_col0" class="data row3 col0" >78.130000</td>
#             </tr>
#             <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row4" class="row_heading level0 row4" >Mexico City</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row4_col0" class="data row4 col0" >77.860000</td>
#             </tr>
#             <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row5" class="row_heading level0 row5" >Detroit</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row5_col0" class="data row5 col0" >76.690000</td>
#             </tr>
#             <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row6" class="row_heading level0 row6" >Porto Alegre</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row6_col0" class="data row6 col0" >76.460000</td>
#             </tr>
#             <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row7" class="row_heading level0 row7" >Noida</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row7_col0" class="data row7 col0" >75.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row8" class="row_heading level0 row8" >Karachi</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row8_col0" class="data row8 col0" >74.360000</td>
#             </tr>
#             <tr>
#                         <th id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002level0_row9" class="row_heading level0 row9" >Rotterdam</th>
#                         <td id="T_2482ee56_2de4_11ec_8f8b_0242ac1c0002row9_col0" class="data row9 col0" >74.270000</td>
#             </tr>
#     </tbody></table>
# Cities having Worst Health care Facility
# <style  type="text/css" >
# #T_248529e6_2de4_11ec_8f8b_0242ac1c0002row0_col0,#T_248529e6_2de4_11ec_8f8b_0242ac1c0002row1_col0{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_248529e6_2de4_11ec_8f8b_0242ac1c0002row2_col0{
#             background-color:  #3b3b52;
#             color:  #f1f1f1;
#         }#T_248529e6_2de4_11ec_8f8b_0242ac1c0002row3_col0{
#             background-color:  #a3c1c3;
#             color:  #000000;
#         }#T_248529e6_2de4_11ec_8f8b_0242ac1c0002row4_col0,#T_248529e6_2de4_11ec_8f8b_0242ac1c0002row5_col0,#T_248529e6_2de4_11ec_8f8b_0242ac1c0002row6_col0,#T_248529e6_2de4_11ec_8f8b_0242ac1c0002row7_col0{
#             background-color:  #ecf3f3;
#             color:  #000000;
#         }#T_248529e6_2de4_11ec_8f8b_0242ac1c0002row8_col0{
#             background-color:  #edf4f4;
#             color:  #000000;
#         }#T_248529e6_2de4_11ec_8f8b_0242ac1c0002row9_col0{
#             background-color:  #ffffff;
#             color:  #000000;
#         }</style><table id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Crime Rating</th>    </tr>    <tr>        <th class="index_name level0" >City</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row0" class="row_heading level0 row0" >Malaga</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row0_col0" class="data row0 col0" >9.110000</td>
#             </tr>
#             <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row1" class="row_heading level0 row1" >Marbella</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row1_col0" class="data row1 col0" >9.110000</td>
#             </tr>
#             <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row2" class="row_heading level0 row2" >Abu Dhabi</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row2_col0" class="data row2 col0" >10.860000</td>
#             </tr>
#             <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row3" class="row_heading level0 row3" >Tokyo</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row3_col0" class="data row3 col0" >13.910000</td>
#             </tr>
#             <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row4" class="row_heading level0 row4" >Munich</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row4_col0" class="data row4 col0" >15.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row5" class="row_heading level0 row5" >Aachen</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row5_col0" class="data row5 col0" >15.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row6" class="row_heading level0 row6" >Dusseldorf</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row6_col0" class="data row6 col0" >15.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row7" class="row_heading level0 row7" >Dresden</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row7_col0" class="data row7 col0" >15.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row8" class="row_heading level0 row8" >Zurich</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row8_col0" class="data row8 col0" >15.350000</td>
#             </tr>
#             <tr>
#                         <th id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002level0_row9" class="row_heading level0 row9" >Taipei</th>
#                         <td id="T_248529e6_2de4_11ec_8f8b_0242ac1c0002row9_col0" class="data row9 col0" >15.710000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Recommending Better Cities to live

# %%
def recommend_better_cities(citi, factor = 'Lifestyle'):
    x = city[['City','Food','Education','Lifestyle','Travel', 'Income']]
    food = x[x['City'] == citi]['Food']
    edu = x[x['City'] == citi]['Education']
    life = x[x['City'] == citi]['Lifestyle']
    travel = x[x['City'] == citi]['Travel']
    income = x[x['City'] == citi]['Income']
    best_cities = x[(x['Food'] <= food.values[0]) & (x['Education'] <= edu.values[0]) & 
                   (x['Lifestyle'] <= life.values[0]) & (x['Travel'] <= travel.values[0]) &
                   (x['Income'] > income.values[0])]
    best = best_cities.sort_values(by = factor, ascending = False).head(10)
    return best['City'].reset_index(drop = True)

# %%
recommend_better_cities('Sydney')
# Out:
# 0     Brisbane
# 1    Las Vegas
# Name: City, dtype: object
